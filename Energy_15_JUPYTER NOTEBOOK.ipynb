# %%
import pandas as pd

df = pd.read_csv('energy_csv.csv')  #df is DataFrame in Pandas

# %%
df.columns = df.columns.str.replace('_', ' ')
df.replace('_', ' ', regex=True)
#all data is from 1980s
#different energy types, their consumption and production in the world and in each country individually
# Out:
#         Country                Energy type  Year  Energy consumption  \
# 0         World           all energy types  1980          292.899790
# 1         World                       coal  1980           78.656134
# 2         World                natural gas  1980           53.865223
# 3         World  petroleum n other liquids  1980          132.064019
# 4         World                    nuclear  1980            7.575700
# ...         ...                        ...   ...                 ...
# 55435  Zimbabwe                       coal  2019            0.045064
# 55436  Zimbabwe                natural gas  2019            0.000000
# 55437  Zimbabwe  petroleum n other liquids  2019            0.055498
# 55438  Zimbabwe                    nuclear  2019                 NaN
# 55439  Zimbabwe         renewables n other  2019            0.068089
#
#        Energy production          GDP
# 0             296.337228  27770.91028
# 1              80.114194  27770.91028
# ...

# %%
df.head()  #headers
# Out:
#    Unnamed: 0 Country                Energy_type  Year  Energy_consumption  \
# 0           0   World           all_energy_types  1980          292.899790
# 1           1   World                       coal  1980           78.656134
# 2           2   World                natural_gas  1980           53.865223
# 3           3   World  petroleum_n_other_liquids  1980          132.064019
# 4           4   World                    nuclear  1980            7.575700
#
#    Energy_production          GDP   Population  Energy_intensity_per_capita  \
# 0         296.337228  27770.91028  4298126.522                    68.145921
# 1          80.114194  27770.91028  4298126.522                    68.145921
# 2          54.761046  27770.91028  4298126.522                    68.145921
# 3         133.111109  27770.91028  4298126.522                    68.145921
# 4           7.575700  27770.91028  4298126.522                    68.145921
#
#    Energy_intensity_by_GDP  CO2_emission
# ...

# %%
df.describe()
#statistical values (mean, quartiles, standard deviation...)
# Out:
#        Unnamed: 0    Year  Energy_consumption  Energy_production          GDP  \
# count    6.000000     6.0            6.000000           6.000000      6.00000
# mean     2.500000  1980.0           97.627202          98.779076  27770.91028
# std      1.870829     0.0          105.469424         106.673840      0.00000
# min      0.000000  1980.0            7.575700           7.575700  27770.91028
# 25%      1.250000  1980.0           28.993064          29.271645  27770.91028
# 50%      2.500000  1980.0           66.260679          67.437620  27770.91028
# 75%      3.750000  1980.0          118.712048         119.861880  27770.91028
# max      5.000000  1980.0          292.899790         296.337228  27770.91028
#
#         Population  Energy_intensity_per_capita  Energy_intensity_by_GDP  \
# count        6.000                     6.000000                    6.000
# mean   4298126.522                    68.145921                   10.547
# ...

# %%
df.head(6)
#table with world consumption in each energy in 1980
# Out:
#   Country                Energy_type  Year  Energy_consumption  \
# 0   World           all_energy_types  1980          292.899790
# 1   World                       coal  1980           78.656134
# 2   World                natural_gas  1980           53.865223
# 3   World  petroleum_n_other_liquids  1980          132.064019
# 4   World                    nuclear  1980            7.575700
# 5   World         renewables_n_other  1980           20.702344
#
#    Energy_production          GDP
# 0         296.337228  27770.91028
# 1          80.114194  27770.91028
# 2          54.761046  27770.91028
# 3         133.111109  27770.91028
# 4           7.575700  27770.91028
# 5          20.775178  27770.91028

# %%
import pandas as pd

df2 = pd.read_csv('energy2_csv.csv')    #only middle eastern countries

# %%
df2.head(89)
# Out:
#           Country                Energy_type  Year  Energy_consumption  \
# 6     Afghanistan           all_energy_types  1980            0.026583
# 7     Afghanistan                       coal  1980            0.002479
# 8     Afghanistan                natural_gas  1980            0.002094
# 9     Afghanistan  petroleum_n_other_liquids  1980            0.014624
# 10    Afghanistan                    nuclear  1980                 NaN
# ...           ...                        ...   ...                 ...
# 7932        Qatar           all_energy_types  1985            0.248324
# 7933        Qatar                       coal  1985            0.000000
# 7934        Qatar                natural_gas  1985            0.199977
# 7935        Qatar  petroleum_n_other_liquids  1985            0.048347
# 7936        Qatar                    nuclear  1985                 NaN
#
#       Energy_production  GDP  Population  Energy_intensity_per_capita  \
# ...

# %%
  #statistical values  
df=df[['Energy_consumption','Energy_production', 'Population', 'Energy_intensity_per_capita']]
df.describe()
# Out:
#        Energy_consumption  Energy_production    Population  \
# count        44287.000000       4.428900e+04  4.601400e+04
# mean             1.537811       1.532700e+00  6.263020e+04
# std             15.456596       1.530356e+01  4.562088e+05
# min             -0.163438      -1.000000e-39  1.147100e+01
# 25%              0.000000       0.000000e+00  1.141950e+03
# 50%              0.018381       5.121971e-04  6.157680e+03
# 75%              0.209422       1.125410e-01  2.004290e+04
# max            601.040490       6.115090e+02  7.714631e+06
#
#        Energy_intensity_per_capita
# count                 50358.000000
# mean                     71.898914
# std                     113.728738
# min                       0.000000
# 25%                       3.799939
# 50%                      29.779260
# 75%                      95.523627
# max                    1139.320598

# %%
df2.sort_values('Energy_consumption', ascending=False)
# Out:
#     Unnamed: 0               Country                Energy_type  Year  \
# 30        1074          Saudi Arabia           all_energy_types  1980
# 12         606                  Iran           all_energy_types  1980
# 33        1077          Saudi Arabia  petroleum_n_other_liquids  1980
# 15         609                  Iran  petroleum_n_other_liquids  1980
# 42        3120                 Egypt           all_energy_types  1982
# ..         ...                   ...                        ...   ...
# 64        5470  United Arab Emirates                    nuclear  1983
# 70        6736                 Syria                    nuclear  1984
# 76        6916                 Yemen                    nuclear  1984
# 82        7018               Bahrain                    nuclear  1985
# 88        7936                 Qatar                    nuclear  1985
#
#     Energy_consumption  Energy_production      GDP  Population  \
# ...

# %%
sorted_df = df2.sort_values('Country')
header_df = pd.DataFrame(columns=sorted_df.columns)
table_df
# Out:
#                    Country  Energy_consumption  Energy_production  \
# 2015                Israel           -0.000618                0.0
# 7937                 Qatar            0.000000                0.0
# 1079          Saudi Arabia            0.000000                0.0
# 3451                Kuwait            0.000000                0.0
# 1075          Saudi Arabia            0.000000                0.0
# ...                    ...                 ...                ...
# 5470  United Arab Emirates                 NaN                NaN
# 6736                 Syria                 NaN                NaN
# 6916                 Yemen                 NaN                NaN
# 7018               Bahrain                 NaN                NaN
# 7936                 Qatar                 NaN                NaN
#
#       Energy_intensity_per_capita
# 2015                    95.712872
# 7937                   669.541850
# 1079                   170.647722
# ...

# %%
import pandas as pd

df3 = pd.read_csv('energy3_csv.csv')

# %%
df3.head(15)
# Out:
#                    Country       Energy_type  Year  Energy_consumption  \
# 6              Afghanistan  all_energy_types  1980            0.026583
# 702                Lebanon  all_energy_types  1980            0.103282
# 606                   Iran  all_energy_types  1980            1.602263
# 612                   Iraq  all_energy_types  1980            0.529373
# 936                   Oman  all_energy_types  1980            0.064639
# 1074          Saudi Arabia  all_energy_types  1980            1.653827
# 2010                Israel  all_energy_types  1981            0.360904
# 3120                 Egypt  all_energy_types  1982            0.923209
# 3450                Kuwait  all_energy_types  1982            0.355833
# 4806                Jordan  all_energy_types  1983            0.111174
# 5466  United Arab Emirates  all_energy_types  1983            0.517691
# 6732                 Syria  all_energy_types  1984            0.369017
# ...

# %%
df3['Energy_production'].sum() #total energy produced in the middle east
# Out:
# 40.749430840817006

# %%
energy_production = df3['Energy_production']
energy_consumption = df3['Energy_consumption']
df3.plot(kind='scatter', x='Energy_consumption', y='Energy_production')
#scatter plot showing the difference between middle eastern countries' production of energy and consumption (big exports since small consumption compared to production)
# Out:
# <AxesSubplot:xlabel='Energy_consumption', ylabel='Energy_production'>

# %%
import pandas as pd

df4 = pd.read_csv('energy4_csv.csv')

# %%
df4.drop(['GDP','Energy_intensity_by_GDP'], axis=1)
df4.head(15)  
#only petroleum and other liquids -->we look at their production with the objective to compare it to their total energy production to show their reliability on petroleum and other liquids already at the time (unfortunately we do not have their GDP to show the importance in their economy, but you can point it out by showing how little they consume compared to how much they produce)
# Out:
#                    Country                Energy_type  Year  \
# 9              Afghanistan  petroleum_n_other_liquids  1980
# 705                Lebanon  petroleum_n_other_liquids  1980
# 609                   Iran  petroleum_n_other_liquids  1980
# 615                   Iraq  petroleum_n_other_liquids  1980
# 939                   Oman  petroleum_n_other_liquids  1980
# 1077          Saudi Arabia  petroleum_n_other_liquids  1980
# 2013                Israel  petroleum_n_other_liquids  1981
# 3123                 Egypt  petroleum_n_other_liquids  1982
# 3453                Kuwait  petroleum_n_other_liquids  1982
# 4809                Jordan  petroleum_n_other_liquids  1983
# 5469  United Arab Emirates  petroleum_n_other_liquids  1983
# 6735                 Syria  petroleum_n_other_liquids  1984
# 6915                 Yemen  petroleum_n_other_liquids  1984
# 7017               Bahrain  petroleum_n_other_liquids  1985
# 7935                 Qatar  petroleum_n_other_liquids  1985
#
# ...

# %%
df4.describe()
# Out:
#               Year  Energy_consumption  Energy_production      GDP  \
# count    15.000000           15.000000          15.000000    1.000
# mean   1981.933333            0.361708           2.590410  179.814
# std       1.944467            0.416406           5.621497      NaN
# min    1980.000000            0.014624           0.000000  179.814
# 25%    1980.000000            0.070980           0.038940  179.814
# 50%    1982.000000            0.251133           0.609099  179.814
# 75%    1983.500000            0.406845           2.232438  179.814
# max    1985.000000            1.304129          22.084850  179.814
#
#          Population  Energy_intensity_per_capita  Energy_intensity_by_GDP  \
# count     15.000000                    15.000000                15.000000
# mean   10272.269867                   159.949229                 0.191936
# std    13804.493179                   209.361847                 0.743363
# ...

# %%
df4['Energy_production'].sum()
#sum of petroleum and other liquids produced in the middle east
# Out:
# 38.8561464549

# %%
df3['Energy_production'].sum()
#sum of all energy produced in the middle east
# Out:
# 40.749430840817006

# %%
38.8561464549/40.749430840817006
# Out:
# 0.953538384540562

# %%
#95% of the middle east's energy production is petroleum and other liquids (not worth it to look at the other energies produced as they are minimal)

# %%
#all petroleum produced in the world from the data is --> 132.064019

# %%
38.8561464549/132.064019
#30% of world petroleum and other liquids produced in the middle east
# Out:
# 0.2942220504049631

# %%
production_by_country = df4.groupby('Country')['Energy_production'].sum()
production_by_country.plot(kind='bar', xlabel='Country', ylabel='Petroleum Production (bbl)', title='Petroleum Production by Middle Eastern Countries in 1980s')
# Out:
# <AxesSubplot:title={'center':'Petroleum Production by Middle Eastern Countries in 1980s'}, xlabel='Country', ylabel='Petroleum Production (bbl)'>

# %%
df4 = pd.read_csv('energy4_csv.csv')
new_df4 = df4.groupby('Country').agg({'Population': 'sum', 'Energy_intensity_per_capita': 'sum'}).reset_index()
new_df4.plot(kind='bar', x='Country', y=['Population', 'Energy_intensity_per_capita'], figsize=(12,8)) 
#low energy consumption
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
df4 = pd.read_csv('energy4_csv.csv')
new_df4 = df4.groupby('Country').agg({'Energy_consumption': 'sum', 'CO2_emission': 'sum'}).reset_index()
new_df4.plot(kind='bar', x='Country', y=['Energy_consumption', 'CO2_emission'], figsize=(12,8)) 
#disproportionate co2 emissions compared to consumption (very polluting to extract petroleum and other liquids)
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
import pandas as pd

df5 = pd.read_csv('energy5_csv.csv')  #jump from the 80s to 2019 to compare evolutions as an opening

# %%
df5.head(95)
# Out:
#     Unnamed: 0      Country                Energy_type  Year  \
# 0        54060  Afghanistan           all_energy_types  2019
# 1        54061  Afghanistan                       coal  2019
# 2        54062  Afghanistan                natural_gas  2019
# 3        54063  Afghanistan  petroleum_n_other_liquids  2019
# 4        54064  Afghanistan                    nuclear  2019
# ..         ...          ...                        ...   ...
# 90       54054        World           all_energy_types  2019
# 91       54055        World                       coal  2019
# 92       54056        World                natural_gas  2019
# 93       54057        World  petroleum_n_other_liquids  2019
# 94       54058        World                    nuclear  2019
#
#     Energy_consumption  Energy_production          GDP   Population  \
# 0             0.122748           0.055210      79.4546    38050.900
# 1             0.044564           0.042336      79.4546    38050.900
# ...

# %%
df5.describe()  #statistical values
# Out:
#          Unnamed: 0    Year  Energy_consumption  Energy_production  \
# count     96.000000    96.0           82.000000          82.000000
# mean   54755.500000  2019.0           15.690306          17.146359
# std      423.622175     0.0           73.181808          74.266848
# min    54054.000000  2019.0            0.000000           0.000000
# 25%    54596.750000  2019.0            0.010188           0.000186
# 50%    54719.500000  2019.0            0.248606           0.103469
# 75%    55077.750000  2019.0            1.618301           3.889880
# max    55427.000000  2019.0          601.040490         611.508969
#
#                  GDP    Population  Energy_intensity_per_capita  \
# count      96.000000  9.600000e+01                    96.000000
# mean     8394.043663  5.065184e+05                   205.069822
# std     30967.907621  1.871107e+06                   216.805267
# min        53.083800  1.483760e+03                     3.225901
# ...

# %%
#world production of petroleum and other liquids in 2019=192.134558

# %%
import pandas as pd

df6 = pd.read_csv('energy6_csv.csv')

# %%
df6.head(15)
# Out:
#     Unnamed: 0               Country                Energy_type  Year  \
# 0        54063           Afghanistan  petroleum_n_other_liquids  2019
# 1        54663                  Iran  petroleum_n_other_liquids  2019
# 2        54669                  Iraq  petroleum_n_other_liquids  2019
# 3        54681                Israel  petroleum_n_other_liquids  2019
# 4        55425                 Yemen  petroleum_n_other_liquids  2019
# 5        55131          Saudi Arabia  petroleum_n_other_liquids  2019
# 6        55059                 Qatar  petroleum_n_other_liquids  2019
# 7        54141               Bahrain  petroleum_n_other_liquids  2019
# 8        54405                 Egypt  petroleum_n_other_liquids  2019
# 9        54705                Jordan  petroleum_n_other_liquids  2019
# 10       54735                Kuwait  petroleum_n_other_liquids  2019
# 11       54759               Lebanon  petroleum_n_other_liquids  2019
# ...

# %%
df6.describe()  #statistical values
# Out:
#          Unnamed: 0    Year  Energy_consumption  Energy_production  \
# count     15.000000    15.0           15.000000          15.000000
# mean   54802.600000  2019.0            1.200645           4.189122
# std      407.094373     0.0            1.616478           6.414892
# min    54063.000000  2019.0            0.048550           0.000000
# 25%    54666.000000  2019.0            0.256303           0.040802
# 50%    54735.000000  2019.0            0.471248           1.517403
# 75%    55095.000000  2019.0            1.684313           6.608596
# max    55425.000000  2019.0            5.984841          23.687926
#
#                GDP     Population  Energy_intensity_per_capita  \
# count    15.000000      15.000000                    15.000000
# mean    440.963433   25977.574667                   213.547199
# std     533.799757   29883.983580                   227.876920
# min      53.083800    1483.760000                     3.225901
# ...

# %%
df6['Energy_production'].sum()
#sum of petroleum and other liquids produced in the middle east in 2019
# Out:
# 62.83682310034

# %%
62.83682310034/192.134558
# Out:
# 0.3270459190394057

# %%
#33% of world's petroleum and other liquids produced in middle east (up from 30%)

# %%
production_by_country = df6.groupby('Country')['Energy_production'].sum()
production_by_country.plot(kind='bar', xlabel='Country', ylabel='Petroleum Production (bbl)', title='Petroleum Production by Middle Eastern Countries in 2019')
# Out:
# <AxesSubplot:title={'center':'Petroleum Production by Middle Eastern Countries in 2019'}, xlabel='Country', ylabel='Petroleum Production (bbl)'>

# %%
import pandas as pd

df7 = pd.read_csv('energy7_csv.csv')

# %%
df7.head(15)
# Out:
#     Unnamed: 0               Country       Energy_type  Year  \
# 0        54060           Afghanistan  all_energy_types  2019
# 1        54660                  Iran  all_energy_types  2019
# 2        54666                  Iraq  all_energy_types  2019
# 3        54678                Israel  all_energy_types  2019
# 4        55422                 Yemen  all_energy_types  2019
# 5        55128          Saudi Arabia  all_energy_types  2019
# 6        55056                 Qatar  all_energy_types  2019
# 7        54138               Bahrain  all_energy_types  2019
# 8        54402                 Egypt  all_energy_types  2019
# 9        54702                Jordan  all_energy_types  2019
# 10       54732                Kuwait  all_energy_types  2019
# 11       54756               Lebanon  all_energy_types  2019
# 12       54990                  Oman  all_energy_types  2019
# 13       55242                 Syria  all_energy_types  2019
# ...

# %%
production_by_country = df7.groupby('Country')['Energy_production'].sum()
production_by_country.plot(kind='bar', xlabel='Country', ylabel='Total Energy Production', title='Total Energy Production by Middle Eastern Countries in 2019')
# Out:
# <AxesSubplot:title={'center':'Total Energy Production by Middle Eastern Countries in 2019'}, xlabel='Country', ylabel='Total Energy Production'>

# %%
import pandas as pd

df8 = pd.read_csv('energy8_csv.csv')

# %%
all_energy = df8[df8['Energy_type'] == 'all_energy_types']
petroleum = df8[df8['Energy_type'] == 'petroleum_n_other_liquids']
merged = pd.merge(all_energy, petroleum, on='Country', suffixes=('_all_energy', '_petroleum'))
ax = merged.plot(kind='bar', x='Country', y=['Energy_production_all_energy', 'Energy_production_petroleum'], rot=45)
ax.set_xlabel('Country')
ax.set_ylabel('Energy production (kWh)') #allows us to put the names sideway to have a cleaner look at the graph
# Out:
# Text(0, 0.5, 'Energy production (kWh)')

# %%
energy_production = df7['Energy_production']
energy_consumption = df7['Energy_consumption']
df7.plot(kind='scatter', x='Energy_consumption', y='Energy_production') 
#big increase in energy consumption as countries developped but still very saml compared to their production for most (especially saudi arabia)
# Out:
# <AxesSubplot:xlabel='Energy_consumption', ylabel='Energy_production'>
